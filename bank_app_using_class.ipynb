# %%
import json
data = {
    '1001': ['simran', 12000, 'passwd', '1601'], # 1601 --> ddmm
    '1002': ['hitesh', 100000, 'passpass', '2110'],
    '1003': ['gulshan', 1200000, 'adminadmin', '3008'],
    '1004': ['rabindra', 12500000, '12345admin', '0406'],
    '1005': ['murtaza', 14000000, '123456789', '1511']
}
with open("bank_data_2.txt","w") as fp:
    json.dump(data,fp)

# %%
import json
from getpass import getpass
class MyBank:
    def __init__(self, filename):
        with open(filename) as fp:
            self.data = json.load(fp)
        self.file = filename
    
    def authenticate(self, acc, passwd):
        if acc in self.data:
            if passwd == self.data[acc][2]:
                self.acc = acc
                return True
            return False
        else:
            return False
        
    def credit(self,acc):
        cr = int(input("\n Enter the Amount ---->"))
        self.data[acc][1]=self.data[acc][1]+cr
        with open("bank_data_2.txt","w") as fp:
            json.dump(self.data,fp)
        print(" TRANSECTION SUCCESSFULL ".center(80,"*"))
        print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
        
        
    def debit(self,acc):
        dr = int(input("\n Enter the Amount ---->"))
        self.data[acc][1] = self.data[acc][1]-dr
        with open("bank_data_2.txt","w") as fp:
            json.dump(self.data,fp)
        print(" TRANSECTION SUCCESSFULL ".center(80,"*"))
        print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
        
        
    def check_balance(self,acc):
        print(f" AMOUNT IS--->{self.data[acc][1]} ".center(80,"-"))
        print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
        
        
    def change_password(self,acc):
        up_pass = getpass("\n Please Enter The Current Password -------->")
        if up_pass == self.data[acc][2]:
            pa = getpass("\n Please Enter The New Password & Min 8 Length of password is 8 ------->")
            count=0
            upr=0
            lwr=0
            sp=0
            for s in pa:
                if s.isnumeric():
                    count+=1
            for d in pa:
                if  d.isupper():
                    upr+=1
            for x in pa:
                if  x.islower():
                    lwr+=1  
            special = "!@#$%^&*()-+?_=,<>/"
            for o in pa:
                if o in special:
                    sp+=1
            if len(pa)>=8:
                if count>=1:
                    if upr>=1:
                        if lwr>=1:
                            if sp>=1:
                                self.data[acc][2] = pa
                                with open("bank_data_2.txt","w") as fp:
                                    json.dump(self.data,fp)
                                print(" YOUR PASSWORD HAS Been UPDATED " .center(80,"*"))
                                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
                            else:
                                print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!".center(80))
                                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
                        else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!".center(80))
                            print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
                    else:
                        print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!".center(80))
                        print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
                else:
                    print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!!!".center(80))
                    print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
            else:
                print(" PLEASE ENTER THE MININUM 8 CHARACTER!!!!!!!!!!!!!!".center(80))
                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
        else:
            print(" Invalid password !!!!!!!!!!!!!".center(80))
            print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
            
    def details(self,acc):
        print("\n Name is ",self.data[acc][0])
        print("\n Balance is ",self.data[acc][1])
        print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
        
        
    def sign_up(self,name,bal):
        while True:
            passw1 = getpass("\n Enter the password --------->")
            count=0
            upr=0
            lwr=0
            sp=0
            for s in passw1:
                if s.isnumeric():
                    count+=1
            for d in passw1:
                if  d.isupper():
                    upr+=1
            for x in passw1:
                if  x.islower():
                    lwr+=1  
            special = "!@#$%^&*()-+?_=,<>/"
            for o in passw1:
                if o in special:
                    sp+=1
            if len(passw1)>=8:
                if count>=1:
                    if upr>=1:
                        if lwr>=1:
                            if sp>=1:
                                dob = getpass("\n Enter your security in dob -------->")
                                month = dob[2:5]
                                date = dob[0:2]
                                if dob.isnumeric():
                                    if int(month)%2==1 and int(month)!=2 and 1<=int(month)<=7:
                                        if 1<=int(date)<=31:
                                            m = [*data]
                                            n = int(m[-1])
                                            self.data[str(n+1)]=[name,bal, passw1,dob]
                                            with open("bank_data_2.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print(" ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print(" PLEASE ENTER A VALID DATE !!!!!!!!!!!!!!!!".center(80))
                                    elif int(month) == 2:
                                        if 1<=int(date)<=29:
                                            m = [*data]
                                            n = int(m[-1])
                                            self.data[str(n+1)] = [name, bal, passw1,dob]
                                            with open("bank_data_2.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print(" ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print(" PLEASE ENTER A VALID DATE!!!!!!!!!!!!!!!!".center(80))
                                    elif int(month)%2==0 and int(month)!=0 and 8<=int(month)<=12:
                                        if 1<=int(date)<=31:
                                            m = [*data]
                                            n = int(m[-1])
                                            self.data[str(n+1)]=[name, bal, passw1,dob]
                                            with open("bank_data_2.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print("CONGRATULATIONS YOUR ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print(" PLEASE ENTER A VALID DATE!!!!!!!!!!!!!!!!!!!".center(80))
                                    elif 1<=int(month)<=12:
                                        if 1<=int(date)<=30:
                                            m = [*data]
                                            n = int(m[-1])
                                            self.data[str(n+1)]=[name, bal, passw1,dob]
                                            with open("bank_data_2.txt","w") as fp:
                                                json.dump(self.data,fp)
                                            print("CONGRATULATIONS YOUR ACCOUNT HAS BEEN OPENED".center(80,"*"))
                                            print()
                                            print("YOUR ACCOUNT NUMBER IS ---->", str(n+1))
                                            print()
                                            print(" THANK YOU ".center(80,"*"))
                                            break
                                        else:
                                            print(" PLEASE ENTER A VALID DATE!!!!!!!!!!!!!!!!!!!".center(80))
                                    else:
                                        print(" ENTER THE VALID DATE!!!!!!!!!!!!!!!!".center(80))
                                else:
                                    print(" ENTER THE VALID DATE!!!!!!!!!!!!!!!!".center(80))
                            else:
                                print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!".center(80))
                        else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!".center(80))
                    else:
                        print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!".center(80))
                else:
                    print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!".center(80))                            
            else:
                print(" PLEASE ENTER THE MININUM 8 CHARACTER!!!!!!!!!!!!!!".center(80))
                
    def forgot_pass(self,ac_):
        new = getpass("\n PLEASE ENTER YOUR NEW PASSWORD AND MINIMUM LENGTH OF PASSWORD IS 8 ".center(80))
        count=0
        upr=0
        lwr=0
        sp=0
        for s in new:
            if s.isnumeric():
                count+=1
        for d in new:
            if  d.isupper():
                upr+=1
        for x in new:
            if  x.islower():
                lwr+=1  
        special = "!@#$%^&*()-+?_=,<>/"
        for o in new:
            if o in special:
                sp+=1
        if len(new)>=8:
            if count>=1:
                if upr>=1:
                    if lwr>=1:
                        if sp>=1:
                            self.data[ac_][2] = new
                            with open("bank_data_2.txt","w") as fp:
                                    json.dump(self.data,fp)
                            print(" PASSWORD UPDATED".center(80,"*"))
                            print()
                        else:
                            print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
                    else:
                        print(" PLEASE ENTER THE STRONG PASSWORD !!!!!!!!!!!!!!!!! ".center(80))
                else:
                    print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!".center(80))
            else:
                print(" PLEASE ENTER THE STRONG PASSWORD!!!!!!!!!!!!!!!!!".center(80))
        else:
            print(" PLEASE ENTER THE MININUM 8 CHARACTER!!!!!!!!!!!!!!".center(80))






        
    
        


        
def main():
    user1 = MyBank("bank_data_2.txt")
    while True:
        print("\n 1. Login\n 2. Signup\n 3. Forgot Password\n 4. Exit\n")
        choice = input("\n PLEASE CHOOSE CHOICE FROM THESE FOUR ITEMS ----->")
        if choice == "1":
            acc = input("\n Enter your Account Number---->")
            passw = getpass("\n Enter the password----->")
            res = user1.authenticate(acc, passw)
            if res:
                print()
                print(f"Hello {data[acc][0]} ! Welcome To My Bank".center(80,"*"))
                print()
                print("\n1. Credit\n2. Debit\n3. Check Balance\n4. Change Password\n5. Details\n6. Log Out\n")
                while True:
                    up = input("\n CHOOSE FROM 1 AT A TIME------>").lower()
                    if up == "1":
                        user1.credit(acc)

                    elif up == "2":
                        user1.debit(acc)

                    elif up == "3":
                        user1.check_balance(acc)

                    elif up == "4":
                        user1.change_password(acc)

                    elif up == "5":
                        user1.details(acc)

                    elif up == "6":
                        break         
            else:
                print("\n EITHER PASSWORD OR ACCOUNT NUMBER IS INCORRECT")
                
                
        elif choice == "2":
            name = input("\n Enter The Name ---->")
            bal = int(input("\n Enter The Balance--->"))
            if bal>=1000:
                user1.sign_up(name,bal)
            else:
                print(" PLEASE ENTER A VALID BALANCE & GREATER 1000!!!!!!!!!!!!!!!!!".center(80))
                
        elif choice == "3":
            ac_ = input("\n ENTER YOUR ACCOUNT NUMBER ")
            if ac_ in data:
                dob = data[ac_][3]
                se = getpass("\n ENTER YOUR SECURITY CODE ")
                if dob == se:
                    user1.forgot_pass(ac_)
                else:
                    print(" SECURITY CODE DOES NOT MATCHED!!!!!!!!!!!!!!!!!!!!!".center(80))
            else:
                print(" INVALID ACCOUNT NUMBER!!!!!!!!!!!!!!!!!!!!!!!!".center(80))
                    
        elif choice == "4":
            break
            
        else:
            print(" PLEASE CHOOSE CHOICE FROM THESE FOUR !!!!!!!!!!!!!!!!!!".center(80))


main()
# Out:
#  1. Login
#  2. Signup
#  3. Forgot Password
#  4. Exit
#
#
#  PLEASE CHOOSE CHOICE FROM THESE FOUR ITEMS ----->1
#
#  Enter your Account Number---->1002
#
#  Enter the password----->········
#
# ***********************Hello hitesh ! Welcome To My Bank************************
#
#
# 1. Credit
# 2. Debit
# 3. Check Balance
# 4. Change Password
# 5. Details
# 6. Log Out
#
#
#  CHOOSE FROM 1 AT A TIME------>1
#
#  Enter the Amount ---->10000
# *************************** TRANSECTION SUCCESSFULL ****************************
#
# 1. Credit
# 2. Debit
# 3. Check Balance
# 4. Change Password
# 5. Details
# 6. Log Out
#
#
#  CHOOSE FROM 1 AT A TIME------>2
#
#  Enter the Amount ---->5000
# *************************** TRANSECTION SUCCESSFULL ****************************
#
# 1. Credit
# 2. Debit
# 3. Check Balance
# 4. Change Password
# 5. Details
# 6. Log Out
#
#
#  CHOOSE FROM 1 AT A TIME------>3
# ----------------------------- AMOUNT IS--->105000 ------------------------------
#
# 1. Credit
# ...
